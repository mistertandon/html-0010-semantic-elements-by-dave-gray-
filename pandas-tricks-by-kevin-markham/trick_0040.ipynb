# %% [markdown]
# ##### DataFrame from multiple CSV files

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import pandas as pd

# %%
from glob import glob

# %%
stock_files = sorted(glob('../csv_files/stock/Sacramentorealestatetransactions-*.csv'))
stock_files
# Out:
# ['../csv_files/stock\\Sacramentorealestatetransactions-1.csv',
#  '../csv_files/stock\\Sacramentorealestatetransactions-2.csv',
#  '../csv_files/stock\\Sacramentorealestatetransactions-3.csv']

# %%
df = pd.concat([pd.read_csv(stock_file) for stock_file in stock_files], ignore_index = True)
df[200:]
# Out:
#                                street            city    zip state  beds  \
# 200                4660 CEDARWOOD WAY      SACRAMENTO  95823    CA     4
# 201                9254 HARROGATE WAY       ELK GROVE  95758    CA     2
# 202                 6716 TAREYTON WAY  CITRUS HEIGHTS  95621    CA     3
# 203                   2028 ROBERT WAY      SACRAMENTO  95825    CA     2
# 204                9346 AIZENBERG CIR       ELK GROVE  95624    CA     2
# 205               4524 LOCH HAVEN WAY      SACRAMENTO  95842    CA     2
# 206             7140 BLUE SPRINGS WAY  CITRUS HEIGHTS  95621    CA     3
# 207                     4631 11TH AVE      SACRAMENTO  95820    CA     2
# 208                    3228 BAGGAN CT        ANTELOPE  95843    CA     3
# 209                  8515 DARTFORD DR      SACRAMENTO  95823    CA     3
# 210                 4500 TIPPWOOD WAY      SACRAMENTO  95842    CA     3
# 211                 2460 EL ROCCO WAY  RANCHO CORDOVA  95670    CA     3
# ...
